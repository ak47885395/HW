# %%
import requests
from bs4 import BeautifulSoup
import re
url="https://movies.yahoo.com.tw/"
resp=requests.get(url)
resp.coding= "utf-8"
soup_id=BeautifulSoup(resp.text , 'lxml')

# %%
html=soup_id.find("select",attrs={"name":"movie_id"})
movie_item=html.find_all("option",attrs={"data-name":re.compile('.*')})  # 本來要等:甚麼 的  但這邊 是會變動的 (電影名稱不可能都一樣
for i in movie_item:                                # regex=".*"  ==>  pattern = re.compile(regex)
    print('Movies: %s , id:%s' %(i["data-name"] , i["value"])   )
# Out:
# Movies: 逆者 , id:10875
# Movies: 巴亞拉魔幻冒險 , id:10851
# Movies: 隱藏的畫家 , id:10841
# Movies: Perfect World ~和你在一起的奇蹟~ , id:10832
# Movies: 心靈咖啡館的驅魔師 , id:10830
# Movies: 6號鬼病床 , id:10826
# Movies: 家靈 , id:10798
# Movies: 陰眼 , id:10795
# Movies: 哈囉少女 , id:10780
# Movies: 怪胎 , id:10733
# Movies: 原本以為只是手機掉了2：被囚禁的殺人魔 , id:10713
# Movies: 拉麵狂 , id:9861
# Movies: 記憶拼圖：20週年數位修復 , id:10849
# Movies: 追殺艾娃 , id:10821
# Movies: 魔鬼剋星2(1989) , id:10836
# Movies: 阿紫 , id:10828
# Movies: 雙面追緝 , id:10824
# Movies: 愛回來的那7天 , id:10820
# Movies: 屍人莊殺人事件 , id:10819
# Movies: 我們仍未知道那天所看見的花名 劇場版 , id:10818
# Movies: ID4星際終結者 , id:10807
# Movies: 北海小英雄 , id:10806
# Movies: 守靈魘 , id:10805
# Movies: 失眠的北風吹來愛情 , id:10790
# Movies: 派遣死神事件簿 , id:10750
# Movies: 好萊塢殺人事件：曼森血案 , id:10531
# Movies: 日間演奏會散場時 , id:10245
# Movies: 鋼鐵雨：深潛行動 , id:10838
# Movies: 超危險駕駛 , id:10712
# Movies: 《新天堂樂園》30週年數位修復版 , id:10825
# Movies: 淒厲人僧前傳 , id:10822
# Movies: 盧貝松之聖女貞德： 數位修復版 , id:10815
# Movies: 野雀之詩 , id:10808
# ...

# %%
movie_id=10713 # 原本以為只是手機掉了2：被囚禁的殺人魔
url_area='https://movies.yahoo.com.tw/api/v1/areas_by_movie_theater'
payload={"movie_id":str(movie_id)}
# 模擬一個header
headers = {
    'authority': 'movies.yahoo.com.tw',
    'method': 'GET',
    'path': '/api/v1/areas_by_movie_theater?movie_id=' + str(movie_id),
    'scheme': 'https',
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'rxx=9s3x2fws06.1g16irnc&v=1; _ga=GA1.3.2056742944.1551651301; GUC=AQEBAQFczFpdm0IfmwSB&s=AQAAACoo4N5D&g=XMsVBw; BX=4hkdk1decm57t&b=3&s=mr; _ga=GA1.4.2056742944.1551651301; nexagesuid=82843256dd234e8e91aa73f2062f8218; browsed_movie=; avi=eyJpdiI6Im1NeWFJRlVRWDR1endEcGRGUGJUbVE9PSIsInZhbHVlIjoickRpU3JuUytmcGl6cjF5OW0rNU9iZz09IiwibWFjIjoiY2VmY2NkNzZmM2NhNjY5YzlkOTcyNjE5OGEyMzU0NWYxOTdmMDRkMDY3OWNmMmZjOTMxYjc5MjI5N2Q5NGE5MiJ9; cmp=t=1559391030&j=0; _gid=GA1.4.779543841.1559391031; XSRF-TOKEN=%3D; m_s=; _gat=1; nexagesd=10',
    'dnt': '1',
    'mv-authorization': '21835b082e15b91a69b3851eec7b31b82ce82afb',
    'referer': 'https://movies.yahoo.com.tw/',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}
response_area_id=requests.get(url_area , params=payload , headers=headers)
print(response_area_id.json())
for p in response_area_id.json():
    print('放映地區: {0}, 代號(area_id): {1}'.format(p['title'], p['area_id']))
# Out:
# [{'area_id': 28, 'title': '台北市', 'priority': 150, 'ts_update': 1547519309}, {'area_id': 8, 'title': '新北市', 'priority': 145, 'ts_update': 1547194527}, {'area_id': 16, 'title': '桃園', 'priority': 140, 'ts_update': 1547452573}, {'area_id': 20, 'title': '新竹', 'priority': 135, 'ts_update': 1547452603}, {'area_id': 2, 'title': '台中', 'priority': 125, 'ts_update': 1547507368}, {'area_id': 10, 'title': '台南', 'priority': 100, 'ts_update': 1547507403}, {'area_id': 17, 'title': '高雄', 'priority': 95, 'ts_update': 1547507403}]
# 放映地區: 台北市, 代號(area_id): 28
# 放映地區: 新北市, 代號(area_id): 8
# 放映地區: 桃園, 代號(area_id): 16
# 放映地區: 新竹, 代號(area_id): 20
# 放映地區: 台中, 代號(area_id): 2
# 放映地區: 台南, 代號(area_id): 10
# 放映地區: 高雄, 代號(area_id): 17

# %%
# 指定放映地區
area_id = 28
url_time= 'https://movies.yahoo.com.tw/movietime_result.html'
payload={"movie_id":str(movie_id) , "area_id":str(area_id)}
response=requests.get(url_time , params=payload)
response.encoding='utf-8'
soup_time=BeautifulSoup(response.text, 'lxml')
movie_date=soup_time.find_all("label", attrs={'for':re.compile("date_[\d]")})
# 列印播放日期
for date in movie_date:
    print("%s %s" % (date.p.string, date.h3.string))
# Out:
# 八月 9
# 八月 10
# 八月 11
# 八月 12
# 八月 13

# %% [markdown]
# # 最後指定觀看的日期，查詢並列印出放映的電影院、放映類型(數位、3D、IMAX 3D...)、放映時間等資訊。

# %%
# 選定要觀看的日期
date = "2020-08-11"
#日期不能比現在日期少

# %%
# 向網站發送請求，獲取上映的電影院及時間資訊
url_sc = "https://movies.yahoo.com.tw/ajax/pc/get_schedule_by_movie"
payload = {'movie_id':str(movie_id),
           'date':date,
           'area_id':str(area_id),
           'theater_id':'',
           'datetime':'',
           'movie_type_id':''}

resp = requests.get(url_sc, params=payload)
#print(resp.json()['view'])  # 若有需要，列印出json原始碼

soup = BeautifulSoup(resp.json()['view'], 'lxml')
html = soup.find_all("ul", attrs={'data-theater_name':re.compile(".*")})
print(html)
# Out:
# [<ul class="area_time _c jq_area_time" data-theater_name="台北樂聲影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=38" data-theater_url="http://www.luxcinema.com.tw/" id="theater_id_38">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=38">台北樂聲影城</a>
# <span>02-23118628</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-cinema="46efa950eafa11e38b12987bdb90dba4" data-date="1597075200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '原本以為只是手機掉了2：被囚禁的殺人魔']" data-movie="5e8569896be347949f1f926c1a2bc6f6" data-movie_date="08.11" data-movie_time="09:45" data-movie_title="原本以為只是手機掉了2：被囚禁的殺人魔" data-movie_type="數位" data-session="5d11c07452514ed4bbfc4c55d8b266e1" data-time="1597110300" id="73927867" name="schedule_list" type="radio" value="2020-08-11 09:45:00"/>
# ...

# %%
#擷取電影院名稱、影片放映類型以及時間表
gabtn=html[0].find_all(class_="gabtn")  # html[0]  ??  (( 不同電影院‵
print(html)   #  為 list   好幾的電影院 有好幾個 場次
#print(gabtn) #一個電影院 有很多 場次
for j in gabtn:  # 用 for 迴圈解掉 list  裡面為 dict 的資料型態
#    print(j)     
   # time_table=j.find("input",attrs={"class":"gabtn"}).find("data-movie_time") # 因為不是html啦 現在是dict 而且find出來是list
#    print(j["data-movie_date"])  
    print("\n")
#for k in html:
 #   print(k)    # html
 #   print(type(k))  #bs4.element.tag
  #  print(k["data-theater_name"])
for i in html:
    print("----------------------------------------------------------------------")
    print("電影院:" , i["data-theater_name"])   #進入到第一間電影院 (( 第一個 ul ) 因為同個 ul不會有第二個 電影院名稱 所以可以這樣
#   print(i)
    movie_type=i.find("span",attrs={"class":"tapR"})  #   print(h.find(class_="tapR").text)
    print("放映類型: " ,movie_type.string)
   # for d in i:

#    time_table=i.find_all(class_="gabtn").find("data-movie_time") # , None ?? 不行ㄝ
   # print(time_table)
    print(i[0][" data-movie_time "]) # 不行??
    i.find_all(class_="gabtn")
#    for t in gabtn:
        #print(t)
 #       print(t["value"])
# Out:
# [<ul class="area_time _c jq_area_time" data-theater_name="台北樂聲影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=38" data-theater_url="http://www.luxcinema.com.tw/" id="theater_id_38">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=38">台北樂聲影城</a>
# <span>02-23118628</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-cinema="46efa950eafa11e38b12987bdb90dba4" data-date="1597075200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '原本以為只是手機掉了2：被囚禁的殺人魔']" data-movie="5e8569896be347949f1f926c1a2bc6f6" data-movie_date="08.11" data-movie_time="09:45" data-movie_title="原本以為只是手機掉了2：被囚禁的殺人魔" data-movie_type="數位" data-session="5d11c07452514ed4bbfc4c55d8b266e1" data-time="1597110300" id="73927867" name="schedule_list" type="radio" value="2020-08-11 09:45:00"/>
# ...

# %%
#擷取電影院名稱、影片放映類型以及時間表
gabtn=html[0].find_all(class_="gabtn")  # html[0]  ??  (( 不同電影院‵
#print(html)   #  為 list   好幾的電影院 有好幾個 場次
#print(gabtn) #一個電影院 有很多 場次
for j in gabtn:  # 用 for 迴圈解掉 list  裡面為 dict 的資料型態
#    print(j)     
   # time_table=j.find("input",attrs={"class":"gabtn"}).find("data-movie_time") # 因為不是html啦 現在是dict 而且find出來是list
#    print(j["data-movie_date"])  
    print("\n")
#for k in html:
 #   print(k)    # html
 #   print(type(k))  #bs4.element.tag
  #  print(k["data-theater_name"])
for i in html:
    print("----------------------------------------------------------------------")
    print("電影院:" , i["data-theater_name"])   #進入到第一間電影院 (( 第一個 ul ) 因為同個 ul不會有第二個 電影院名稱 所以可以這樣
#   print(i)                                   # 不然就是 i 進入 html 的時候 用取出屬性的話只會掃 
    movie_type=i.find("span",attrs={"class":"tapR"})  #   ''' 前面有一樣的 標籤 用 find   '''
    print("放映類型: " ,movie_type.string            # span 是標籤  屬性是 class 
   # for d in i:
#    print(i['class'])     #   '''        此行證明了 取屬性只會取第一個                                  '''
#    print(i.li)         #  這行同上
#    print(i.li['class'])  # adds 同上
#    time_table=i.find(class_="gabtn")#   '''     因為 class屬性有太多個 用find                        '''
#    print(time_table)                          #  發現  find class 之後 會給整個 標籤
#    xx=time_table["data-movie_time"]    #    
 #   print(xx)
   # print(time_table)
    gabtn = i.find_all(class_="gabtn") 
#    print(gabtn)    #list 
    for t in gabtn:
#        print(t)
        print(t["value"])
# Out:
# ----------------------------------------------------------------------
# 電影院: 台北樂聲影城
# 放映類型:  數位
# 2020-08-11 09:45:00
# 2020-08-11 16:45:00
# 2020-08-11 20:00:00
# ----------------------------------------------------------------------
# 電影院: 台北信義威秀影城
# 放映類型:  數位
# 2020-08-11 12:15:00
# 2020-08-11 16:30:00
# 2020-08-11 21:25:00
# ----------------------------------------------------------------------
# 電影院: 京站威秀影城
# 放映類型:  數位
# 2020-08-11 14:20:00
# 2020-08-11 18:30:00
# ----------------------------------------------------------------------
# 電影院: 喜樂時代影城南港店
# 放映類型:  數位
# 2020-08-11 12:25:00
# 2020-08-11 18:00:00
# 2020-08-11 20:15:00
# 2020-08-11 22:30:00
